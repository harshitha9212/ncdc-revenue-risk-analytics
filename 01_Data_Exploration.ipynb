# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Harshitha

# %%
import pandas as pd

df = pd.read_csv('revenue_streams.csv')
print(df)
# Out:
#       Income_Stream  Year_1_Revenue  Churn_Risk Stability
# 0  Fertilizer_Sales      5927862.09        0.15    Medium
# 1     Rental_Income      1279410.88        0.10      High
# 2    PDS_Commission       936447.31        0.20      High
# 3       Food_Grains       173232.00        0.35       Low
# 4    MSP_Commission        25650.00        0.40       Low

# %%
df['Share_Pct'] = df['Year_1_Revenue'] / df['Year_1_Revenue'].sum() * 100
print(df[['Income_Stream', 'Share_Pct']])
# Out:
#       Income_Stream  Share_Pct
# 0  Fertilizer_Sales  71.055312
# 1     Rental_Income  15.335873
# 2    PDS_Commission  11.224883
# 3       Food_Grains   2.076474
# 4    MSP_Commission   0.307458
